# %%
# !git add .
# !git commit -m "Initial commit - genai04 project"
# !git branch -M main
# !git push -u origin main
# Out:
# [master 2e8ce4b] Initial commit - genai04 project
#  11 files changed, 321 deletions(-)
#  delete mode 100644 datasets/bibtex/cityscapes.tex
#  delete mode 100644 datasets/bibtex/facades.tex
#  delete mode 100644 datasets/bibtex/handbags.tex
#  delete mode 100644 datasets/bibtex/shoes.tex
#  delete mode 100644 datasets/bibtex/transattr.tex
#  delete mode 100644 datasets/combine_A_and_B.py
#  delete mode 100755 datasets/download_cyclegan_dataset.sh
#  delete mode 100755 datasets/download_pix2pix_dataset.sh
#  delete mode 100644 datasets/make_dataset_aligned.py
#  delete mode 100644 datasets/prepare_cityscapes_dataset.py
#  create mode 100644 results.zip
# fatal: could not read Username for 'https://github.com': No such device or address
